# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../outputs/spotify_powerbi_ready.csv')
print(f"Data ready! {len(df):,} songs")
print(df['popularity_tier'].value_counts())
# Out:
# Data ready! 80,481 songs
# popularity_tier
# Low     48027
# Mid     30098
# High     2356
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

features = ['danceability', 'energy', 'valence', 
            'loudness', 'acousticness', 'instrumentalness']

X = df[features]
y = df['popularity_tier']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

print(f"Training songs: {len(X_train):,}")
print(f"Testing songs: {len(X_test):,}")
# Out:
# Training songs: 64,384
# Testing songs: 16,097

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Train the model
model = DecisionTreeClassifier(max_depth=5)
model.fit(X_train, y_train)

# Test accuracy
predictions = model.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
print(f"Model Accuracy: {accuracy:.2%}")
# Out:
# Model Accuracy: 60.66%

# %%
import matplotlib.pyplot as plt

importance = pd.Series(model.feature_importances_, index=features)
importance.sort_values().plot(kind='barh', color='#1DB954')
plt.title('Which Audio Features Predict Popularity Most?')
plt.xlabel('Importance Score')
plt.tight_layout()
plt.savefig('../outputs/feature_importance.png', dpi=150)
plt.show()

# %%
def predict_song(danceability, energy, valence, 
                 loudness, acousticness, instrumentalness):
    
    # Put the values into a dataframe
    song = pd.DataFrame([[danceability, energy, valence,
                          loudness, acousticness, instrumentalness]],
                        columns=features)
    
    # Predict
    result = model.predict(song)[0]
    
    print(f"Predicted Popularity: {result}")
    
    if result == 'High':
        print("This song has HIGH chances of being popular! 🔥")
    elif result == 'Mid':
        print("This song has MODERATE chances of being popular 👍")
    else:
        print("This song may struggle to gain popularity 📉")

# Test it with a typical pop song
predict_song(
    danceability=0.8,
    energy=0.7,
    valence=0.6,
    loudness=-5.0,
    acousticness=0.1,
    instrumentalness=0.0
)
# Out:
# Predicted Popularity: Low
# This song may struggle to gain popularity 📉
